# %%
import numpy as np
import pandas as pd

import SeasonData as sdata

# %% [markdown]
# ## 3. Nettoyage des données

# %%
def additional_features(df: pd.DataFrame) -> pd.DataFrame:
    """Add additional features to the dataframe"""

    # Add shot distance

    # Define the Euclidian distance function
    dist_euclidian = lambda x1, x2: np.round(np.linalg.norm(np.array(x1 - x2)), decimals=1)

    # Add shot distance based on the ice coordinates
    df['shotDistance'] = df.apply(
        lambda x: dist_euclidian(x['iceCoord'], np.array([-89, 0])) if x['iceCoord'][0] <= 0
        else dist_euclidian(x['iceCoord'], np.array([89, 0])), axis=1)
    return df

# %%
def minutes_to_seconds(df: pd.DataFrame, column: str) -> pd.DataFrame:
    """
    Convert dataframe column from 'minutes:seconds' to 'seconds' and add the number of period
    """
    # Split columns into 'minutes' and 'seconds' and 'number of period' as integer
    df['minutes'] = df[column].str.split(':').str[0].astype(int)
    df['seconds'] = df[column].str.split(':').str[1].astype(int)
    df['numberPeriod'] = df['currentPeriod'].str.split("/").str[0].astype(int)

    # Total in seconds
    df[column] = df['minutes'] * 60 + df['seconds'] + 20 * 60 * (df['numberPeriod'] - 1)

    #Drop columns
    df.drop(['minutes', 'seconds', 'numberPeriod'], axis=1, inplace=True)

    return df

# %%
def extract_players(game_nhl: dict) -> pd.DataFrame:
    """Extract the play-by-play data from the game dictionary"""

    # Extract player data
    df_players = pd.DataFrame(game_nhl['rosterSpots'])[['playerId', 'firstName', 'lastName']]

    # Keep the default name for each player (first and last name)
    df_players['firstName'] = df_players['firstName'].apply(lambda x: x['default'])
    df_players['lastName'] = df_players['lastName'].apply(lambda x: x['default'])
    return df_players

# %%
def extract_teams(game_nhl: dict) -> pd.DataFrame:
    """Extract 'home' and 'away' teams"""
    home_team = {'teamId': game_nhl['homeTeam']['id'], 'teamName': game_nhl['homeTeam']['name']['default'],
                 'teamSide': 'home'}
    away_team = {'teamId': game_nhl['awayTeam']['id'], 'teamName': game_nhl['awayTeam']['name']['default'],
                 'teamSide': 'away'}
    return pd.DataFrame([home_team, away_team])

# %%
def process_period_data(df: pd.DataFrame) -> pd.DataFrame:
    """Decompose periodDescriptor and return processed dataframe."""
    
    # Split 'periodDescriptor' into 'periodType', 'number', and 'maxRegulationPeriods'
    df_period = pd.DataFrame(df['periodDescriptor'].tolist())

    # Convert 'number' and 'maxRegulationPeriods' columns as strings
    df_period[['number', 'maxRegulationPeriods']] = df_period[['number', 'maxRegulationPeriods']].astype(str)
    return df_period

# %%
def process_event_details(df: pd.DataFrame, df_players: pd.DataFrame) -> pd.DataFrame:
    """Process event details and merge with player information."""
    df_details = pd.DataFrame(df['details'].tolist())
    
    # Combine x and y coordinates into a tuple
    df_details['iceCoord'] = df_details[['xCoord', 'yCoord']].apply(tuple, axis=1)

    # Merge 'shooting' and 'scoring' player, to keep only one column
    df_details['shootingPlayerId'] = df_details['shootingPlayerId'].fillna(0) + df_details['scoringPlayerId'].fillna(0)
    
    # Fill missing 'goalieInNetId' values with 0
    df_details['goalieInNetId'] = df_details['goalieInNetId'].fillna(0)
    
    # Convert 'shootingPlayerId' and 'goalieInNetId' as integer
    df_details['shootingPlayerId'] = df_details['shootingPlayerId'].astype(int)
    df_details['goalieInNetId'] = df_details['goalieInNetId'].astype('Int64')  # Int64: handling NaN values

    # Add the shooter names by merging IDs
    df_details = pd.merge(df_players, df_details, left_on='playerId', right_on='shootingPlayerId', how='right').drop(
        columns=['playerId'])

    # Keep only full name
    df_details['shootingPlayer'] = df_details['firstName'] + ' ' + df_details['lastName']
    df_details.drop(['firstName', 'lastName'], axis=1, inplace=True)

    # Add the goalies names by merging IDs 
    df_details = pd.merge(df_players, df_details, left_on='playerId', right_on='goalieInNetId', how='right').drop(
        columns=['playerId'])

    # Keep only full name
    df_details['goaliePlayer'] = df_details['firstName'] + ' ' + df_details['lastName']
    df_details.drop(['firstName', 'lastName'], axis=1, inplace=True)

    return df_details

# %%
def calculate_empty_goal_net(df: pd.DataFrame) -> pd.Series:
    """Determine if the goal net is empty"""
    return df.apply(lambda x: x['situationCode'][3] if x['teamSide'] == 'away' else x['situationCode'][0], axis=1).map(
        {'0': True, '1': False})

# %%
def determine_goal_advantage(df: pd.DataFrame) -> pd.Series:
    """Determine if the event team is in advantage, disadvantage, or neutral situation"""
    return df.apply(lambda x: "Advantage" if (int(x['situationCode'][1]) > int(x['situationCode'][2]) and x[
        'teamSide'] == 'away') or (int(x['situationCode'][2]) > int(x['situationCode'][1]) and x[
        'teamSide'] == 'home')
    else "Disadvantage" if (int(x['situationCode'][1]) < int(x['situationCode'][2]) and x['teamSide'] == 'away') or
                           (int(x['situationCode'][2]) < int(x['situationCode'][1]) and x['teamSide'] == 'home')
    else 'Neutral', axis=1)

# %%
def convert_event_to_dataframe(game_nhl: dict) -> pd.DataFrame:
    """
    Convert NHL game event data into a clean dataframe  
    :param game_nhl: Dictionary containing the data of the NHL game
    :return: A Pandas DataFrame containing filtered data
    """
    # Extract play-by-play data
    df_pbp = pd.DataFrame(game_nhl['plays'])

    # Extract player and team data
    df_players = extract_players(game_nhl)
    df_teams = extract_teams(game_nhl)

    # Create a new dataframe for the event data
    clean_df = pd.DataFrame(df_pbp[['periodDescriptor', 'timeInPeriod', 'situationCode', 'typeDescKey', 'details']])

    # Insert the game ID as the first column
    clean_df.insert(0, 'idGame', game_nhl['id'])

    # Filter to keep only events of type 'shot-on-goal' or 'goal'
    clean_df = clean_df[(clean_df['typeDescKey'] == 'shot-on-goal') | (clean_df['typeDescKey'] == 'goal')].reset_index(
        drop=True)

    # Create a dataframe to decompose the period descriptor fields
    df_period = process_period_data(clean_df)
    clean_df.drop('periodDescriptor', axis=1, inplace=True)

    # Add 'periodType' and 'currentPeriod' columns to the new dataframe
    clean_df.insert(1, 'periodType', df_period['periodType'])
    clean_df.insert(2, 'currentPeriod', df_period['number'] + '/' + df_period['maxRegulationPeriods'])

    # Parse the game's start time to UTC
    start_time = pd.to_datetime(game_nhl['startTimeUTC'])

    # Convert time in the period to seconds and add it to the game start time
    clean_df = minutes_to_seconds(clean_df, 'timeInPeriod')
    clean_df['timeInPeriod'] = start_time + pd.to_timedelta(clean_df['timeInPeriod'], unit='s')

    # Process event details and merge player information
    df_details = process_event_details(clean_df, df_players)
    clean_df.drop('details', axis=1, inplace=True)

    # Add team data by merging IDs
    df_details = pd.merge(df_teams, df_details, left_on='teamId', right_on='eventOwnerTeamId', how='right')

    # Add the extracted data to the new dataframe
    clean_df['iceCoord'] = df_details['iceCoord']
    clean_df['shootingPlayer'] = df_details['shootingPlayer']
    clean_df['goaliePlayer'] = df_details['goaliePlayer']
    clean_df['shotType'] = df_details['shotType']
    clean_df.insert(5, 'eventOwnerTeam', df_details['teamName'])
    clean_df['teamSide'] = df_details['teamSide']

    # Calculate emptyGoalNet and goal advantage
    clean_df['emptyGoalNet'] = calculate_empty_goal_net(clean_df)
    clean_df['isGoalAdvantage'] = determine_goal_advantage(clean_df)

    # Add shot distance
    clean_df = additional_features(clean_df)

    return clean_df

# %%
def get_data_from(first_year: int, last_year: int) -> dict:
    
    '''
    Retrieves game data for each season within the specified range of years, processes the events of each game
    (focusing on shots), and organizes the information into a dictionary. The dictionary's keys are the years,
    and the corresponding values are lists of DataFrames, where each DataFrame represents all the shots taken 
    in a particular game during that year.

    Parameters:
    - first (int): The first year (inclusive) from which to retrieve data.
    - last (int): The last year (inclusive) from which to retrieve data.

    Returns:
    - dict: A dictionary where the keys are years, and the values are lists of DataFrames. Each DataFrame corresponds
    to a single game in the specified year and contains information about the shots taken during that game.
    
    '''
    
    all_games_dictionary = {} # Initialize the return dictionary
    data = sdata.NHLData() # Initialize the data object
    
    # Loop over all years
    for year in range(first_year, last_year+1):
        
        # Generate the data from API or local if available
        data.fetch_regular_season(year=year)
        data.fetch_playoffs(year=year)
        yearly_data = data.regular_season[year] + data.playoffs[year] # List with all the games in a year
        
        # Add all the cleaned dataframes (shots per game) for a year to the dictionary
        all_games_dictionary[year] = [convert_event_to_dataframe(game) for game in yearly_data]
    
    return all_games_dictionary

# %% [markdown]
# Cette ligne de code est un exemple d'utilisation de la fonction get_data_from()

# %%
# This gets all the cleaned data from 2022 to 2023 (inclusive) in a dictionary (key: year)
data_2017_2023 = get_data_from(2022,2023)
data_2017_2023[2022][123].head() # Année 2022, 124eme partie, 5 premières ligne
# Out:
# Data was successfully imported: data/regular_season/2022/2022_0001.json
# Data was successfully imported: data/regular_season/2022/2022_0002.json
# Data was successfully imported: data/regular_season/2022/2022_0003.json
# Data was successfully imported: data/regular_season/2022/2022_0004.json
# Data was successfully imported: data/regular_season/2022/2022_0005.json
# Data was successfully imported: data/regular_season/2022/2022_0006.json
# Data was successfully imported: data/regular_season/2022/2022_0007.json
# Data was successfully imported: data/regular_season/2022/2022_0008.json
# Data was successfully imported: data/regular_season/2022/2022_0009.json
# Data was successfully imported: data/regular_season/2022/2022_0010.json
# Data was successfully imported: data/regular_season/2022/2022_0011.json
# Data was successfully imported: data/regular_season/2022/2022_0012.json
# Data was successfully imported: data/regular_season/2022/2022_0013.json
# Data was successfully imported: data/regular_season/2022/2022_0014.json
# Data was successfully imported: data/regular_season/2022/2022_0015.json
# Data was successfully imported: data/regular_season/2022/2022_0016.json
# Data was successfully imported: data/regular_season/2022/2022_0017.json
# Data was successfully imported: data/regular_season/2022/2022_0018.json
# Data was successfully imported: data/regular_season/2022/2022_0019.json
# Data was successfully imported: data/regular_season/2022/2022_0020.json
# Data was successfully imported: data/regular_season/2022/2022_0021.json
# Data was successfully imported: data/regular_season/2022/2022_0022.json
# Data was successfully imported: data/regular_season/2022/2022_0023.json
# Data was successfully imported: data/regular_season/2022/2022_0024.json
# Data was successfully imported: data/regular_season/2022/2022_0025.json
# Data was successfully imported: data/regular_season/2022/2022_0026.json
# Data was successfully imported: data/regular_season/2022/2022_0027.json
# Data was successfully imported: data/regular_season/2022/2022_0028.json
# Data was successfully imported: data/regular_season/2022/2022_0029.json
# Data was successfully imported: data/regular_season/2022/2022_0030.json
# Data was successfully imported: data/regular_season/2022/2022_0031.json
# Data was successfully imported: data/regular_season/2022/2022_0032.json
# Data was successfully imported: data/regular_season/2022/2022_0033.json
# Data was successfully imported: data/regular_season/2022/2022_0034.json
# Data was successfully imported: data/regular_season/2022/2022_0035.json
# Data was successfully imported: data/regular_season/2022/2022_0036.json
# Data was successfully imported: data/regular_season/2022/2022_0037.json
# Data was successfully imported: data/regular_season/2022/2022_0038.json
# Data was successfully imported: data/regular_season/2022/2022_0039.json
# Data was successfully imported: data/regular_season/2022/2022_0040.json
# Data was successfully imported: data/regular_season/2022/2022_0041.json
# Data was successfully imported: data/regular_season/2022/2022_0042.json
# Data was successfully imported: data/regular_season/2022/2022_0043.json
# Data was successfully imported: data/regular_season/2022/2022_0044.json
# Data was successfully imported: data/regular_season/2022/2022_0045.json
# Data was successfully imported: data/regular_season/2022/2022_0046.json
# Data was successfully imported: data/regular_season/2022/2022_0047.json
# Data was successfully imported: data/regular_season/2022/2022_0048.json
# Data was successfully imported: data/regular_season/2022/2022_0049.json
# Data was successfully imported: data/regular_season/2022/2022_0050.json
# Data was successfully imported: data/regular_season/2022/2022_0051.json
# Data was successfully imported: data/regular_season/2022/2022_0052.json
# Data was successfully imported: data/regular_season/2022/2022_0053.json
# Data was successfully imported: data/regular_season/2022/2022_0054.json
# Data was successfully imported: data/regular_season/2022/2022_0055.json
# Data was successfully imported: data/regular_season/2022/2022_0056.json
# Data was successfully imported: data/regular_season/2022/2022_0057.json
# Data was successfully imported: data/regular_season/2022/2022_0058.json
# Data was successfully imported: data/regular_season/2022/2022_0059.json
# Data was successfully imported: data/regular_season/2022/2022_0060.json
# Data was successfully imported: data/regular_season/2022/2022_0061.json
# Data was successfully imported: data/regular_season/2022/2022_0062.json
# Data was successfully imported: data/regular_season/2022/2022_0063.json
# Data was successfully imported: data/regular_season/2022/2022_0064.json
# Data was successfully imported: data/regular_season/2022/2022_0065.json
# Data was successfully imported: data/regular_season/2022/2022_0066.json
# Data was successfully imported: data/regular_season/2022/2022_0067.json
# Data was successfully imported: data/regular_season/2022/2022_0068.json
# Data was successfully imported: data/regular_season/2022/2022_0069.json
# Data was successfully imported: data/regular_season/2022/2022_0070.json
# Data was successfully imported: data/regular_season/2022/2022_0071.json
# Data was successfully imported: data/regular_season/2022/2022_0072.json
# Data was successfully imported: data/regular_season/2022/2022_0073.json
# Data was successfully imported: data/regular_season/2022/2022_0074.json
# Data was successfully imported: data/regular_season/2022/2022_0075.json
# Data was successfully imported: data/regular_season/2022/2022_0076.json
# Data was successfully imported: data/regular_season/2022/2022_0077.json
# Data was successfully imported: data/regular_season/2022/2022_0078.json
# Data was successfully imported: data/regular_season/2022/2022_0079.json
# Data was successfully imported: data/regular_season/2022/2022_0080.json
# Data was successfully imported: data/regular_season/2022/2022_0081.json
# Data was successfully imported: data/regular_season/2022/2022_0082.json
# Data was successfully imported: data/regular_season/2022/2022_0083.json
# Data was successfully imported: data/regular_season/2022/2022_0084.json
# Data was successfully imported: data/regular_season/2022/2022_0085.json
# Data was successfully imported: data/regular_season/2022/2022_0086.json
# Data was successfully imported: data/regular_season/2022/2022_0087.json
# Data was successfully imported: data/regular_season/2022/2022_0088.json
# Data was successfully imported: data/regular_season/2022/2022_0089.json
# Data was successfully imported: data/regular_season/2022/2022_0090.json
# Data was successfully imported: data/regular_season/2022/2022_0091.json
# Data was successfully imported: data/regular_season/2022/2022_0092.json
# Data was successfully imported: data/regular_season/2022/2022_0093.json
# Data was successfully imported: data/regular_season/2022/2022_0094.json
# Data was successfully imported: data/regular_season/2022/2022_0095.json
# Data was successfully imported: data/regular_season/2022/2022_0096.json
# Data was successfully imported: data/regular_season/2022/2022_0097.json
# Data was successfully imported: data/regular_season/2022/2022_0098.json
# Data was successfully imported: data/regular_season/2022/2022_0099.json
# Data was successfully imported: data/regular_season/2022/2022_0100.json
# Data was successfully imported: data/regular_season/2022/2022_0101.json
# Data was successfully imported: data/regular_season/2022/2022_0102.json
# Data was successfully imported: data/regular_season/2022/2022_0103.json
# Data was successfully imported: data/regular_season/2022/2022_0104.json
# Data was successfully imported: data/regular_season/2022/2022_0105.json
# Data was successfully imported: data/regular_season/2022/2022_0106.json
# Data was successfully imported: data/regular_season/2022/2022_0107.json
# Data was successfully imported: data/regular_season/2022/2022_0108.json
# Data was successfully imported: data/regular_season/2022/2022_0109.json
# Data was successfully imported: data/regular_season/2022/2022_0110.json
# Data was successfully imported: data/regular_season/2022/2022_0111.json
# Data was successfully imported: data/regular_season/2022/2022_0112.json
# Data was successfully imported: data/regular_season/2022/2022_0113.json
# Data was successfully imported: data/regular_season/2022/2022_0114.json
# Data was successfully imported: data/regular_season/2022/2022_0115.json
# Data was successfully imported: data/regular_season/2022/2022_0116.json
# Data was successfully imported: data/regular_season/2022/2022_0117.json
# Data was successfully imported: data/regular_season/2022/2022_0118.json
# Data was successfully imported: data/regular_season/2022/2022_0119.json
# Data was successfully imported: data/regular_season/2022/2022_0120.json
# Data was successfully imported: data/regular_season/2022/2022_0121.json
# Data was successfully imported: data/regular_season/2022/2022_0122.json
# Data was successfully imported: data/regular_season/2022/2022_0123.json
# Data was successfully imported: data/regular_season/2022/2022_0124.json
# Data was successfully imported: data/regular_season/2022/2022_0125.json
# Data was successfully imported: data/regular_season/2022/2022_0126.json
# Data was successfully imported: data/regular_season/2022/2022_0127.json
# Data was successfully imported: data/regular_season/2022/2022_0128.json
# Data was successfully imported: data/regular_season/2022/2022_0129.json
# Data was successfully imported: data/regular_season/2022/2022_0130.json
# Data was successfully imported: data/regular_season/2022/2022_0131.json
# Data was successfully imported: data/regular_season/2022/2022_0132.json
# Data was successfully imported: data/regular_season/2022/2022_0133.json
# Data was successfully imported: data/regular_season/2022/2022_0134.json
# Data was successfully imported: data/regular_season/2022/2022_0135.json
# Data was successfully imported: data/regular_season/2022/2022_0136.json
# Data was successfully imported: data/regular_season/2022/2022_0137.json
# Data was successfully imported: data/regular_season/2022/2022_0138.json
# Data was successfully imported: data/regular_season/2022/2022_0139.json
# Data was successfully imported: data/regular_season/2022/2022_0140.json
# Data was successfully imported: data/regular_season/2022/2022_0141.json
# Data was successfully imported: data/regular_season/2022/2022_0142.json
# Data was successfully imported: data/regular_season/2022/2022_0143.json
# Data was successfully imported: data/regular_season/2022/2022_0144.json
# Data was successfully imported: data/regular_season/2022/2022_0145.json
# Data was successfully imported: data/regular_season/2022/2022_0146.json
# Data was successfully imported: data/regular_season/2022/2022_0147.json
# Data was successfully imported: data/regular_season/2022/2022_0148.json
# Data was successfully imported: data/regular_season/2022/2022_0149.json
# Data was successfully imported: data/regular_season/2022/2022_0150.json
# Data was successfully imported: data/regular_season/2022/2022_0151.json
# Data was successfully imported: data/regular_season/2022/2022_0152.json
# Data was successfully imported: data/regular_season/2022/2022_0153.json
# Data was successfully imported: data/regular_season/2022/2022_0154.json
# Data was successfully imported: data/regular_season/2022/2022_0155.json
# Data was successfully imported: data/regular_season/2022/2022_0156.json
# Data was successfully imported: data/regular_season/2022/2022_0157.json
# Data was successfully imported: data/regular_season/2022/2022_0158.json
# Data was successfully imported: data/regular_season/2022/2022_0159.json
# Data was successfully imported: data/regular_season/2022/2022_0160.json
# Data was successfully imported: data/regular_season/2022/2022_0161.json
# Data was successfully imported: data/regular_season/2022/2022_0162.json
# Data was successfully imported: data/regular_season/2022/2022_0163.json
# Data was successfully imported: data/regular_season/2022/2022_0164.json
# Data was successfully imported: data/regular_season/2022/2022_0165.json
# Data was successfully imported: data/regular_season/2022/2022_0166.json
# Data was successfully imported: data/regular_season/2022/2022_0167.json
# Data was successfully imported: data/regular_season/2022/2022_0168.json
# Data was successfully imported: data/regular_season/2022/2022_0169.json
# Data was successfully imported: data/regular_season/2022/2022_0170.json
# Data was successfully imported: data/regular_season/2022/2022_0171.json
# Data was successfully imported: data/regular_season/2022/2022_0172.json
# Data was successfully imported: data/regular_season/2022/2022_0173.json
# Data was successfully imported: data/regular_season/2022/2022_0174.json
# Data was successfully imported: data/regular_season/2022/2022_0175.json
# Data was successfully imported: data/regular_season/2022/2022_0176.json
# Data was successfully imported: data/regular_season/2022/2022_0177.json
# Data was successfully imported: data/regular_season/2022/2022_0178.json
# Data was successfully imported: data/regular_season/2022/2022_0179.json
# Data was successfully imported: data/regular_season/2022/2022_0180.json
# Data was successfully imported: data/regular_season/2022/2022_0181.json
# Data was successfully imported: data/regular_season/2022/2022_0182.json
# Data was successfully imported: data/regular_season/2022/2022_0183.json
# Data was successfully imported: data/regular_season/2022/2022_0184.json
# Data was successfully imported: data/regular_season/2022/2022_0185.json
# Data was successfully imported: data/regular_season/2022/2022_0186.json
# Data was successfully imported: data/regular_season/2022/2022_0187.json
# Data was successfully imported: data/regular_season/2022/2022_0188.json
# Data was successfully imported: data/regular_season/2022/2022_0189.json
# Data was successfully imported: data/regular_season/2022/2022_0190.json
# Data was successfully imported: data/regular_season/2022/2022_0191.json
# Data was successfully imported: data/regular_season/2022/2022_0192.json
# Data was successfully imported: data/regular_season/2022/2022_0193.json
# Data was successfully imported: data/regular_season/2022/2022_0194.json
# Data was successfully imported: data/regular_season/2022/2022_0195.json
# Data was successfully imported: data/regular_season/2022/2022_0196.json
# Data was successfully imported: data/regular_season/2022/2022_0197.json
# Data was successfully imported: data/regular_season/2022/2022_0198.json
# Data was successfully imported: data/regular_season/2022/2022_0199.json
# Data was successfully imported: data/regular_season/2022/2022_0200.json
# Data was successfully imported: data/regular_season/2022/2022_0201.json
# Data was successfully imported: data/regular_season/2022/2022_0202.json
# Data was successfully imported: data/regular_season/2022/2022_0203.json
# Data was successfully imported: data/regular_season/2022/2022_0204.json
# Data was successfully imported: data/regular_season/2022/2022_0205.json
# Data was successfully imported: data/regular_season/2022/2022_0206.json
# Data was successfully imported: data/regular_season/2022/2022_0207.json
# Data was successfully imported: data/regular_season/2022/2022_0208.json
# Data was successfully imported: data/regular_season/2022/2022_0209.json
# Data was successfully imported: data/regular_season/2022/2022_0210.json
# Data was successfully imported: data/regular_season/2022/2022_0211.json
# Data was successfully imported: data/regular_season/2022/2022_0212.json
# Data was successfully imported: data/regular_season/2022/2022_0213.json
# Data was successfully imported: data/regular_season/2022/2022_0214.json
# Data was successfully imported: data/regular_season/2022/2022_0215.json
# Data was successfully imported: data/regular_season/2022/2022_0216.json
# Data was successfully imported: data/regular_season/2022/2022_0217.json
# Data was successfully imported: data/regular_season/2022/2022_0218.json
# Data was successfully imported: data/regular_season/2022/2022_0219.json
# Data was successfully imported: data/regular_season/2022/2022_0220.json
# Data was successfully imported: data/regular_season/2022/2022_0221.json
# Data was successfully imported: data/regular_season/2022/2022_0222.json
# Data was successfully imported: data/regular_season/2022/2022_0223.json
# Data was successfully imported: data/regular_season/2022/2022_0224.json
# Data was successfully imported: data/regular_season/2022/2022_0225.json
# Data was successfully imported: data/regular_season/2022/2022_0226.json
# Data was successfully imported: data/regular_season/2022/2022_0227.json
# Data was successfully imported: data/regular_season/2022/2022_0228.json
# Data was successfully imported: data/regular_season/2022/2022_0229.json
# Data was successfully imported: data/regular_season/2022/2022_0230.json
# Data was successfully imported: data/regular_season/2022/2022_0231.json
# Data was successfully imported: data/regular_season/2022/2022_0232.json
# Data was successfully imported: data/regular_season/2022/2022_0233.json
# Data was successfully imported: data/regular_season/2022/2022_0234.json
# Data was successfully imported: data/regular_season/2022/2022_0235.json
# Data was successfully imported: data/regular_season/2022/2022_0236.json
# Data was successfully imported: data/regular_season/2022/2022_0237.json
# Data was successfully imported: data/regular_season/2022/2022_0238.json
# Data was successfully imported: data/regular_season/2022/2022_0239.json
# Data was successfully imported: data/regular_season/2022/2022_0240.json
# Data was successfully imported: data/regular_season/2022/2022_0241.json
# Data was successfully imported: data/regular_season/2022/2022_0242.json
# Data was successfully imported: data/regular_season/2022/2022_0243.json
# Data was successfully imported: data/regular_season/2022/2022_0244.json
# Data was successfully imported: data/regular_season/2022/2022_0245.json
# Data was successfully imported: data/regular_season/2022/2022_0246.json
# Data was successfully imported: data/regular_season/2022/2022_0247.json
# Data was successfully imported: data/regular_season/2022/2022_0248.json
# Data was successfully imported: data/regular_season/2022/2022_0249.json
# Data was successfully imported: data/regular_season/2022/2022_0250.json
# Data was successfully imported: data/regular_season/2022/2022_0251.json
# Data was successfully imported: data/regular_season/2022/2022_0252.json
# Data was successfully imported: data/regular_season/2022/2022_0253.json
# Data was successfully imported: data/regular_season/2022/2022_0254.json
# Data was successfully imported: data/regular_season/2022/2022_0255.json
# Data was successfully imported: data/regular_season/2022/2022_0256.json
# Data was successfully imported: data/regular_season/2022/2022_0257.json
# Data was successfully imported: data/regular_season/2022/2022_0258.json
# Data was successfully imported: data/regular_season/2022/2022_0259.json
# Data was successfully imported: data/regular_season/2022/2022_0260.json
# Data was successfully imported: data/regular_season/2022/2022_0261.json
# Data was successfully imported: data/regular_season/2022/2022_0262.json
# Data was successfully imported: data/regular_season/2022/2022_0263.json
# Data was successfully imported: data/regular_season/2022/2022_0264.json
# Data was successfully imported: data/regular_season/2022/2022_0265.json
# Data was successfully imported: data/regular_season/2022/2022_0266.json
# Data was successfully imported: data/regular_season/2022/2022_0267.json
# Data was successfully imported: data/regular_season/2022/2022_0268.json
# Data was successfully imported: data/regular_season/2022/2022_0269.json
# Data was successfully imported: data/regular_season/2022/2022_0270.json
# Data was successfully imported: data/regular_season/2022/2022_0271.json
# Data was successfully imported: data/regular_season/2022/2022_0272.json
# Data was successfully imported: data/regular_season/2022/2022_0273.json
# Data was successfully imported: data/regular_season/2022/2022_0274.json
# Data was successfully imported: data/regular_season/2022/2022_0275.json
# Data was successfully imported: data/regular_season/2022/2022_0276.json
# Data was successfully imported: data/regular_season/2022/2022_0277.json
# Data was successfully imported: data/regular_season/2022/2022_0278.json
# Data was successfully imported: data/regular_season/2022/2022_0279.json
# Data was successfully imported: data/regular_season/2022/2022_0280.json
# Data was successfully imported: data/regular_season/2022/2022_0281.json
# Data was successfully imported: data/regular_season/2022/2022_0282.json
# Data was successfully imported: data/regular_season/2022/2022_0283.json
# Data was successfully imported: data/regular_season/2022/2022_0284.json
# Data was successfully imported: data/regular_season/2022/2022_0285.json
# Data was successfully imported: data/regular_season/2022/2022_0286.json
# Data was successfully imported: data/regular_season/2022/2022_0287.json
# Data was successfully imported: data/regular_season/2022/2022_0288.json
# Data was successfully imported: data/regular_season/2022/2022_0289.json
# Data was successfully imported: data/regular_season/2022/2022_0290.json
# Data was successfully imported: data/regular_season/2022/2022_0291.json
# Data was successfully imported: data/regular_season/2022/2022_0292.json
# Data was successfully imported: data/regular_season/2022/2022_0293.json
# Data was successfully imported: data/regular_season/2022/2022_0294.json
# Data was successfully imported: data/regular_season/2022/2022_0295.json
# Data was successfully imported: data/regular_season/2022/2022_0296.json
# Data was successfully imported: data/regular_season/2022/2022_0297.json
# Data was successfully imported: data/regular_season/2022/2022_0298.json
# Data was successfully imported: data/regular_season/2022/2022_0299.json
# Data was successfully imported: data/regular_season/2022/2022_0300.json
# Data was successfully imported: data/regular_season/2022/2022_0301.json
# Data was successfully imported: data/regular_season/2022/2022_0302.json
# Data was successfully imported: data/regular_season/2022/2022_0303.json
# Data was successfully imported: data/regular_season/2022/2022_0304.json
# Data was successfully imported: data/regular_season/2022/2022_0305.json
# Data was successfully imported: data/regular_season/2022/2022_0306.json
# Data was successfully imported: data/regular_season/2022/2022_0307.json
# Data was successfully imported: data/regular_season/2022/2022_0308.json
# Data was successfully imported: data/regular_season/2022/2022_0309.json
# Data was successfully imported: data/regular_season/2022/2022_0310.json
# Data was successfully imported: data/regular_season/2022/2022_0311.json
# Data was successfully imported: data/regular_season/2022/2022_0312.json
# Data was successfully imported: data/regular_season/2022/2022_0313.json
# Data was successfully imported: data/regular_season/2022/2022_0314.json
# Data was successfully imported: data/regular_season/2022/2022_0315.json
# Data was successfully imported: data/regular_season/2022/2022_0316.json
# Data was successfully imported: data/regular_season/2022/2022_0317.json
# Data was successfully imported: data/regular_season/2022/2022_0318.json
# Data was successfully imported: data/regular_season/2022/2022_0319.json
# Data was successfully imported: data/regular_season/2022/2022_0320.json
# Data was successfully imported: data/regular_season/2022/2022_0321.json
# Data was successfully imported: data/regular_season/2022/2022_0322.json
# Data was successfully imported: data/regular_season/2022/2022_0323.json
# Data was successfully imported: data/regular_season/2022/2022_0324.json
# Data was successfully imported: data/regular_season/2022/2022_0325.json
# Data was successfully imported: data/regular_season/2022/2022_0326.json
# Data was successfully imported: data/regular_season/2022/2022_0327.json
# Data was successfully imported: data/regular_season/2022/2022_0328.json
# Data was successfully imported: data/regular_season/2022/2022_0329.json
# Data was successfully imported: data/regular_season/2022/2022_0330.json
# Data was successfully imported: data/regular_season/2022/2022_0331.json
# Data was successfully imported: data/regular_season/2022/2022_0332.json
# Data was successfully imported: data/regular_season/2022/2022_0333.json
# Data was successfully imported: data/regular_season/2022/2022_0334.json
# Data was successfully imported: data/regular_season/2022/2022_0335.json
# Data was successfully imported: data/regular_season/2022/2022_0336.json
# Data was successfully imported: data/regular_season/2022/2022_0337.json
# Data was successfully imported: data/regular_season/2022/2022_0338.json
# Data was successfully imported: data/regular_season/2022/2022_0339.json
# Data was successfully imported: data/regular_season/2022/2022_0340.json
# Data was successfully imported: data/regular_season/2022/2022_0341.json
# Data was successfully imported: data/regular_season/2022/2022_0342.json
# Data was successfully imported: data/regular_season/2022/2022_0343.json
# Data was successfully imported: data/regular_season/2022/2022_0344.json
# Data was successfully imported: data/regular_season/2022/2022_0345.json
# Data was successfully imported: data/regular_season/2022/2022_0346.json
# Data was successfully imported: data/regular_season/2022/2022_0347.json
# Data was successfully imported: data/regular_season/2022/2022_0348.json
# Data was successfully imported: data/regular_season/2022/2022_0349.json
# Data was successfully imported: data/regular_season/2022/2022_0350.json
# Data was successfully imported: data/regular_season/2022/2022_0351.json
# Data was successfully imported: data/regular_season/2022/2022_0352.json
# Data was successfully imported: data/regular_season/2022/2022_0353.json
# Data was successfully imported: data/regular_season/2022/2022_0354.json
# Data was successfully imported: data/regular_season/2022/2022_0355.json
# Data was successfully imported: data/regular_season/2022/2022_0356.json
# Data was successfully imported: data/regular_season/2022/2022_0357.json
# Data was successfully imported: data/regular_season/2022/2022_0358.json
# Data was successfully imported: data/regular_season/2022/2022_0359.json
# Data was successfully imported: data/regular_season/2022/2022_0360.json
# Data was successfully imported: data/regular_season/2022/2022_0361.json
# Data was successfully imported: data/regular_season/2022/2022_0362.json
# Data was successfully imported: data/regular_season/2022/2022_0363.json
# Data was successfully imported: data/regular_season/2022/2022_0364.json
# Data was successfully imported: data/regular_season/2022/2022_0365.json
# Data was successfully imported: data/regular_season/2022/2022_0366.json
# Data was successfully imported: data/regular_season/2022/2022_0367.json
# Data was successfully imported: data/regular_season/2022/2022_0368.json
# Data was successfully imported: data/regular_season/2022/2022_0369.json
# Data was successfully imported: data/regular_season/2022/2022_0370.json
# Data was successfully imported: data/regular_season/2022/2022_0371.json
# Data was successfully imported: data/regular_season/2022/2022_0372.json
# Data was successfully imported: data/regular_season/2022/2022_0373.json
# Data was successfully imported: data/regular_season/2022/2022_0374.json
# Data was successfully imported: data/regular_season/2022/2022_0375.json
# Data was successfully imported: data/regular_season/2022/2022_0376.json
# Data was successfully imported: data/regular_season/2022/2022_0377.json
# Data was successfully imported: data/regular_season/2022/2022_0378.json
# Data was successfully imported: data/regular_season/2022/2022_0379.json
# Data was successfully imported: data/regular_season/2022/2022_0380.json
# Data was successfully imported: data/regular_season/2022/2022_0381.json
# Data was successfully imported: data/regular_season/2022/2022_0382.json
# Data was successfully imported: data/regular_season/2022/2022_0383.json
# Data was successfully imported: data/regular_season/2022/2022_0384.json
# Data was successfully imported: data/regular_season/2022/2022_0385.json
# Data was successfully imported: data/regular_season/2022/2022_0386.json
# Data was successfully imported: data/regular_season/2022/2022_0387.json
# Data was successfully imported: data/regular_season/2022/2022_0388.json
# Data was successfully imported: data/regular_season/2022/2022_0389.json
# Data was successfully imported: data/regular_season/2022/2022_0390.json
# Data was successfully imported: data/regular_season/2022/2022_0391.json
# Data was successfully imported: data/regular_season/2022/2022_0392.json
# Data was successfully imported: data/regular_season/2022/2022_0393.json
# Data was successfully imported: data/regular_season/2022/2022_0394.json
# Data was successfully imported: data/regular_season/2022/2022_0395.json
# Data was successfully imported: data/regular_season/2022/2022_0396.json
# Data was successfully imported: data/regular_season/2022/2022_0397.json
# Data was successfully imported: data/regular_season/2022/2022_0398.json
# Data was successfully imported: data/regular_season/2022/2022_0399.json
# Data was successfully imported: data/regular_season/2022/2022_0400.json
# Data was successfully imported: data/regular_season/2022/2022_0401.json
# Data was successfully imported: data/regular_season/2022/2022_0402.json
# Data was successfully imported: data/regular_season/2022/2022_0403.json
# Data was successfully imported: data/regular_season/2022/2022_0404.json
# Data was successfully imported: data/regular_season/2022/2022_0405.json
# Data was successfully imported: data/regular_season/2022/2022_0406.json
# Data was successfully imported: data/regular_season/2022/2022_0407.json
# Data was successfully imported: data/regular_season/2022/2022_0408.json
# Data was successfully imported: data/regular_season/2022/2022_0409.json
# Data was successfully imported: data/regular_season/2022/2022_0410.json
# Data was successfully imported: data/regular_season/2022/2022_0411.json
# Data was successfully imported: data/regular_season/2022/2022_0412.json
# Data was successfully imported: data/regular_season/2022/2022_0413.json
# Data was successfully imported: data/regular_season/2022/2022_0414.json
# Data was successfully imported: data/regular_season/2022/2022_0415.json
# Data was successfully imported: data/regular_season/2022/2022_0416.json
# Data was successfully imported: data/regular_season/2022/2022_0417.json
# Data was successfully imported: data/regular_season/2022/2022_0418.json
# Data was successfully imported: data/regular_season/2022/2022_0419.json
# Data was successfully imported: data/regular_season/2022/2022_0420.json
# Data was successfully imported: data/regular_season/2022/2022_0421.json
# Data was successfully imported: data/regular_season/2022/2022_0422.json
# Data was successfully imported: data/regular_season/2022/2022_0423.json
# Data was successfully imported: data/regular_season/2022/2022_0424.json
# Data was successfully imported: data/regular_season/2022/2022_0425.json
# Data was successfully imported: data/regular_season/2022/2022_0426.json
# Data was successfully imported: data/regular_season/2022/2022_0427.json
# Data was successfully imported: data/regular_season/2022/2022_0428.json
# Data was successfully imported: data/regular_season/2022/2022_0429.json
# Data was successfully imported: data/regular_season/2022/2022_0430.json
# Data was successfully imported: data/regular_season/2022/2022_0431.json
# Data was successfully imported: data/regular_season/2022/2022_0432.json
# Data was successfully imported: data/regular_season/2022/2022_0433.json
# Data was successfully imported: data/regular_season/2022/2022_0434.json
# Data was successfully imported: data/regular_season/2022/2022_0435.json
# Data was successfully imported: data/regular_season/2022/2022_0436.json
# Data was successfully imported: data/regular_season/2022/2022_0437.json
# Data was successfully imported: data/regular_season/2022/2022_0438.json
# Data was successfully imported: data/regular_season/2022/2022_0439.json
# Data was successfully imported: data/regular_season/2022/2022_0440.json
# Data was successfully imported: data/regular_season/2022/2022_0441.json
# Data was successfully imported: data/regular_season/2022/2022_0442.json
# Data was successfully imported: data/regular_season/2022/2022_0443.json
# Data was successfully imported: data/regular_season/2022/2022_0444.json
# Data was successfully imported: data/regular_season/2022/2022_0445.json
# Data was successfully imported: data/regular_season/2022/2022_0446.json
# Data was successfully imported: data/regular_season/2022/2022_0447.json
# Data was successfully imported: data/regular_season/2022/2022_0448.json
# Data was successfully imported: data/regular_season/2022/2022_0449.json
# Data was successfully imported: data/regular_season/2022/2022_0450.json
# Data was successfully imported: data/regular_season/2022/2022_0451.json
# Data was successfully imported: data/regular_season/2022/2022_0452.json
# Data was successfully imported: data/regular_season/2022/2022_0453.json
# Data was successfully imported: data/regular_season/2022/2022_0454.json
# Data was successfully imported: data/regular_season/2022/2022_0455.json
# Data was successfully imported: data/regular_season/2022/2022_0456.json
# Data was successfully imported: data/regular_season/2022/2022_0457.json
# Data was successfully imported: data/regular_season/2022/2022_0458.json
# Data was successfully imported: data/regular_season/2022/2022_0459.json
# Data was successfully imported: data/regular_season/2022/2022_0460.json
# Data was successfully imported: data/regular_season/2022/2022_0461.json
# Data was successfully imported: data/regular_season/2022/2022_0462.json
# Data was successfully imported: data/regular_season/2022/2022_0463.json
# Data was successfully imported: data/regular_season/2022/2022_0464.json
# Data was successfully imported: data/regular_season/2022/2022_0465.json
# Data was successfully imported: data/regular_season/2022/2022_0466.json
# Data was successfully imported: data/regular_season/2022/2022_0467.json
# Data was successfully imported: data/regular_season/2022/2022_0468.json
# Data was successfully imported: data/regular_season/2022/2022_0469.json
# Data was successfully imported: data/regular_season/2022/2022_0470.json
# Data was successfully imported: data/regular_season/2022/2022_0471.json
# Data was successfully imported: data/regular_season/2022/2022_0472.json
# Data was successfully imported: data/regular_season/2022/2022_0473.json
# Data was successfully imported: data/regular_season/2022/2022_0474.json
# Data was successfully imported: data/regular_season/2022/2022_0475.json
# Data was successfully imported: data/regular_season/2022/2022_0476.json
# Data was successfully imported: data/regular_season/2022/2022_0477.json
# Data was successfully imported: data/regular_season/2022/2022_0478.json
# Data was successfully imported: data/regular_season/2022/2022_0479.json
# Data was successfully imported: data/regular_season/2022/2022_0480.json
# Data was successfully imported: data/regular_season/2022/2022_0481.json
# Data was successfully imported: data/regular_season/2022/2022_0482.json
# Data was successfully imported: data/regular_season/2022/2022_0483.json
# Data was successfully imported: data/regular_season/2022/2022_0484.json
# Data was successfully imported: data/regular_season/2022/2022_0485.json
# Data was successfully imported: data/regular_season/2022/2022_0486.json
# Data was successfully imported: data/regular_season/2022/2022_0487.json
# Data was successfully imported: data/regular_season/2022/2022_0488.json
# Data was successfully imported: data/regular_season/2022/2022_0489.json
# Data was successfully imported: data/regular_season/2022/2022_0490.json
# Data was successfully imported: data/regular_season/2022/2022_0491.json
# Data was successfully imported: data/regular_season/2022/2022_0492.json
# Data was successfully imported: data/regular_season/2022/2022_0493.json
# Data was successfully imported: data/regular_season/2022/2022_0494.json
# Data was successfully imported: data/regular_season/2022/2022_0495.json
# Data was successfully imported: data/regular_season/2022/2022_0496.json
# Data was successfully imported: data/regular_season/2022/2022_0497.json
# Data was successfully imported: data/regular_season/2022/2022_0498.json
# Data was successfully imported: data/regular_season/2022/2022_0499.json
# Data was successfully imported: data/regular_season/2022/2022_0500.json
# Data was successfully imported: data/regular_season/2022/2022_0501.json
# Data was successfully imported: data/regular_season/2022/2022_0502.json
# Data was successfully imported: data/regular_season/2022/2022_0503.json
# Data was successfully imported: data/regular_season/2022/2022_0504.json
# Data was successfully imported: data/regular_season/2022/2022_0505.json
# Data was successfully imported: data/regular_season/2022/2022_0506.json
# Data was successfully imported: data/regular_season/2022/2022_0507.json
# Data was successfully imported: data/regular_season/2022/2022_0508.json
# Data was successfully imported: data/regular_season/2022/2022_0509.json
# Data was successfully imported: data/regular_season/2022/2022_0510.json
# Data was successfully imported: data/regular_season/2022/2022_0511.json
# Data was successfully imported: data/regular_season/2022/2022_0512.json
# Data was successfully imported: data/regular_season/2022/2022_0513.json
# Data was successfully imported: data/regular_season/2022/2022_0514.json
# Data was successfully imported: data/regular_season/2022/2022_0515.json
# Data was successfully imported: data/regular_season/2022/2022_0516.json
# Data was successfully imported: data/regular_season/2022/2022_0517.json
# Data was successfully imported: data/regular_season/2022/2022_0518.json
# Data was successfully imported: data/regular_season/2022/2022_0519.json
# Data was successfully imported: data/regular_season/2022/2022_0520.json
# Data was successfully imported: data/regular_season/2022/2022_0521.json
# Data was successfully imported: data/regular_season/2022/2022_0522.json
# Data was successfully imported: data/regular_season/2022/2022_0523.json
# Data was successfully imported: data/regular_season/2022/2022_0524.json
# Data was successfully imported: data/regular_season/2022/2022_0525.json
# Data was successfully imported: data/regular_season/2022/2022_0526.json
# Data was successfully imported: data/regular_season/2022/2022_0527.json
# Data was successfully imported: data/regular_season/2022/2022_0528.json
# Data was successfully imported: data/regular_season/2022/2022_0529.json
# Data was successfully imported: data/regular_season/2022/2022_0530.json
# Data was successfully imported: data/regular_season/2022/2022_0531.json
# Data was successfully imported: data/regular_season/2022/2022_0532.json
# Data was successfully imported: data/regular_season/2022/2022_0533.json
# Data was successfully imported: data/regular_season/2022/2022_0534.json
# Data was successfully imported: data/regular_season/2022/2022_0535.json
# Data was successfully imported: data/regular_season/2022/2022_0536.json
# Data was successfully imported: data/regular_season/2022/2022_0537.json
# Data was successfully imported: data/regular_season/2022/2022_0538.json
# Data was successfully imported: data/regular_season/2022/2022_0539.json
# Data was successfully imported: data/regular_season/2022/2022_0540.json
# Data was successfully imported: data/regular_season/2022/2022_0541.json
# Data was successfully imported: data/regular_season/2022/2022_0542.json
# Data was successfully imported: data/regular_season/2022/2022_0543.json
# Data was successfully imported: data/regular_season/2022/2022_0544.json
# Data was successfully imported: data/regular_season/2022/2022_0545.json
# Data was successfully imported: data/regular_season/2022/2022_0546.json
# Data was successfully imported: data/regular_season/2022/2022_0547.json
# Data was successfully imported: data/regular_season/2022/2022_0548.json
# Data was successfully imported: data/regular_season/2022/2022_0549.json
# Data was successfully imported: data/regular_season/2022/2022_0550.json
# Data was successfully imported: data/regular_season/2022/2022_0551.json
# Data was successfully imported: data/regular_season/2022/2022_0552.json
# Data was successfully imported: data/regular_season/2022/2022_0553.json
# Data was successfully imported: data/regular_season/2022/2022_0554.json
# Data was successfully imported: data/regular_season/2022/2022_0555.json
# Data was successfully imported: data/regular_season/2022/2022_0556.json
# Data was successfully imported: data/regular_season/2022/2022_0557.json
# Data was successfully imported: data/regular_season/2022/2022_0558.json
# Data was successfully imported: data/regular_season/2022/2022_0559.json
# Data was successfully imported: data/regular_season/2022/2022_0560.json
# Data was successfully imported: data/regular_season/2022/2022_0561.json
# Data was successfully imported: data/regular_season/2022/2022_0562.json
# Data was successfully imported: data/regular_season/2022/2022_0563.json
# Data was successfully imported: data/regular_season/2022/2022_0564.json
# Data was successfully imported: data/regular_season/2022/2022_0565.json
# Data was successfully imported: data/regular_season/2022/2022_0566.json
# Data was successfully imported: data/regular_season/2022/2022_0567.json
# Data was successfully imported: data/regular_season/2022/2022_0568.json
# Data was successfully imported: data/regular_season/2022/2022_0569.json
# Data was successfully imported: data/regular_season/2022/2022_0570.json
# Data was successfully imported: data/regular_season/2022/2022_0571.json
# Data was successfully imported: data/regular_season/2022/2022_0572.json
# Data was successfully imported: data/regular_season/2022/2022_0573.json
# Data was successfully imported: data/regular_season/2022/2022_0574.json
# Data was successfully imported: data/regular_season/2022/2022_0575.json
# Data was successfully imported: data/regular_season/2022/2022_0576.json
# Data was successfully imported: data/regular_season/2022/2022_0577.json
# Data was successfully imported: data/regular_season/2022/2022_0578.json
# Data was successfully imported: data/regular_season/2022/2022_0579.json
# Data was successfully imported: data/regular_season/2022/2022_0580.json
# Data was successfully imported: data/regular_season/2022/2022_0581.json
# Data was successfully imported: data/regular_season/2022/2022_0582.json
# Data was successfully imported: data/regular_season/2022/2022_0583.json
# Data was successfully imported: data/regular_season/2022/2022_0584.json
# Data was successfully imported: data/regular_season/2022/2022_0585.json
# Data was successfully imported: data/regular_season/2022/2022_0586.json
# Data was successfully imported: data/regular_season/2022/2022_0587.json
# Data was successfully imported: data/regular_season/2022/2022_0588.json
# Data was successfully imported: data/regular_season/2022/2022_0589.json
# Data was successfully imported: data/regular_season/2022/2022_0590.json
# Data was successfully imported: data/regular_season/2022/2022_0591.json
# Data was successfully imported: data/regular_season/2022/2022_0592.json
# Data was successfully imported: data/regular_season/2022/2022_0593.json
# Data was successfully imported: data/regular_season/2022/2022_0594.json
# Data was successfully imported: data/regular_season/2022/2022_0595.json
# Data was successfully imported: data/regular_season/2022/2022_0596.json
# Data was successfully imported: data/regular_season/2022/2022_0597.json
# Data was successfully imported: data/regular_season/2022/2022_0598.json
# Data was successfully imported: data/regular_season/2022/2022_0599.json
# Data was successfully imported: data/regular_season/2022/2022_0600.json
# Data was successfully imported: data/regular_season/2022/2022_0601.json
# Data was successfully imported: data/regular_season/2022/2022_0602.json
# Data was successfully imported: data/regular_season/2022/2022_0603.json
# Data was successfully imported: data/regular_season/2022/2022_0604.json
# Data was successfully imported: data/regular_season/2022/2022_0605.json
# Data was successfully imported: data/regular_season/2022/2022_0606.json
# Data was successfully imported: data/regular_season/2022/2022_0607.json
# Data was successfully imported: data/regular_season/2022/2022_0608.json
# Data was successfully imported: data/regular_season/2022/2022_0609.json
# Data was successfully imported: data/regular_season/2022/2022_0610.json
# Data was successfully imported: data/regular_season/2022/2022_0611.json
# Data was successfully imported: data/regular_season/2022/2022_0612.json
# Data was successfully imported: data/regular_season/2022/2022_0613.json
# Data was successfully imported: data/regular_season/2022/2022_0614.json
# Data was successfully imported: data/regular_season/2022/2022_0615.json
# Data was successfully imported: data/regular_season/2022/2022_0616.json
# Data was successfully imported: data/regular_season/2022/2022_0617.json
# Data was successfully imported: data/regular_season/2022/2022_0618.json
# Data was successfully imported: data/regular_season/2022/2022_0619.json
# Data was successfully imported: data/regular_season/2022/2022_0620.json
# Data was successfully imported: data/regular_season/2022/2022_0621.json
# Data was successfully imported: data/regular_season/2022/2022_0622.json
# Data was successfully imported: data/regular_season/2022/2022_0623.json
# Data was successfully imported: data/regular_season/2022/2022_0624.json
# Data was successfully imported: data/regular_season/2022/2022_0625.json
# Data was successfully imported: data/regular_season/2022/2022_0626.json
# Data was successfully imported: data/regular_season/2022/2022_0627.json
# Data was successfully imported: data/regular_season/2022/2022_0628.json
# Data was successfully imported: data/regular_season/2022/2022_0629.json
# Data was successfully imported: data/regular_season/2022/2022_0630.json
# Data was successfully imported: data/regular_season/2022/2022_0631.json
# Data was successfully imported: data/regular_season/2022/2022_0632.json
# Data was successfully imported: data/regular_season/2022/2022_0633.json
# Data was successfully imported: data/regular_season/2022/2022_0634.json
# Data was successfully imported: data/regular_season/2022/2022_0635.json
# Data was successfully imported: data/regular_season/2022/2022_0636.json
# Data was successfully imported: data/regular_season/2022/2022_0637.json
# Data was successfully imported: data/regular_season/2022/2022_0638.json
# Data was successfully imported: data/regular_season/2022/2022_0639.json
# Data was successfully imported: data/regular_season/2022/2022_0640.json
# Data was successfully imported: data/regular_season/2022/2022_0641.json
# Data was successfully imported: data/regular_season/2022/2022_0642.json
# Data was successfully imported: data/regular_season/2022/2022_0643.json
# Data was successfully imported: data/regular_season/2022/2022_0644.json
# Data was successfully imported: data/regular_season/2022/2022_0645.json
# Data was successfully imported: data/regular_season/2022/2022_0646.json
# Data was successfully imported: data/regular_season/2022/2022_0647.json
# Data was successfully imported: data/regular_season/2022/2022_0648.json
# Data was successfully imported: data/regular_season/2022/2022_0649.json
# Data was successfully imported: data/regular_season/2022/2022_0650.json
# Data was successfully imported: data/regular_season/2022/2022_0651.json
# Data was successfully imported: data/regular_season/2022/2022_0652.json
# Data was successfully imported: data/regular_season/2022/2022_0653.json
# Data was successfully imported: data/regular_season/2022/2022_0654.json
# Data was successfully imported: data/regular_season/2022/2022_0655.json
# Data was successfully imported: data/regular_season/2022/2022_0656.json
# Data was successfully imported: data/regular_season/2022/2022_0657.json
# Data was successfully imported: data/regular_season/2022/2022_0658.json
# Data was successfully imported: data/regular_season/2022/2022_0659.json
# Data was successfully imported: data/regular_season/2022/2022_0660.json
# Data was successfully imported: data/regular_season/2022/2022_0661.json
# Data was successfully imported: data/regular_season/2022/2022_0662.json
# Data was successfully imported: data/regular_season/2022/2022_0663.json
# Data was successfully imported: data/regular_season/2022/2022_0664.json
# Data was successfully imported: data/regular_season/2022/2022_0665.json
# Data was successfully imported: data/regular_season/2022/2022_0666.json
# ...
# Data was successfully imported: data/regular_season/2023/2023_1193.json
# Data was successfully imported: data/regular_season/2023/2023_1194.json
# Data was successfully imported: data/regular_season/2023/2023_1195.json
# Data was successfully imported: data/regular_season/2023/2023_1196.json
# Data was successfully imported: data/regular_season/2023/2023_1197.json
# Data was successfully imported: data/regular_season/2023/2023_1198.json
# Data was successfully imported: data/regular_season/2023/2023_1199.json
# Data was successfully imported: data/regular_season/2023/2023_1200.json
# Data was successfully imported: data/regular_season/2023/2023_1201.json
# Data was successfully imported: data/regular_season/2023/2023_1202.json
# Data was successfully imported: data/regular_season/2023/2023_1203.json
# Data was successfully imported: data/regular_season/2023/2023_1204.json
# Data was successfully imported: data/regular_season/2023/2023_1205.json
# Data was successfully imported: data/regular_season/2023/2023_1206.json
# Data was successfully imported: data/regular_season/2023/2023_1207.json
# Data was successfully imported: data/regular_season/2023/2023_1208.json
# Data was successfully imported: data/regular_season/2023/2023_1209.json
# Data was successfully imported: data/regular_season/2023/2023_1210.json
# Data was successfully imported: data/regular_season/2023/2023_1211.json
# Data was successfully imported: data/regular_season/2023/2023_1212.json
# Data was successfully imported: data/regular_season/2023/2023_1213.json
# Data was successfully imported: data/regular_season/2023/2023_1214.json
# Data was successfully imported: data/regular_season/2023/2023_1215.json
# Data was successfully imported: data/regular_season/2023/2023_1216.json
# Data was successfully imported: data/regular_season/2023/2023_1217.json
# Data was successfully imported: data/regular_season/2023/2023_1218.json
# Data was successfully imported: data/regular_season/2023/2023_1219.json
# Data was successfully imported: data/regular_season/2023/2023_1220.json
# Data was successfully imported: data/regular_season/2023/2023_1221.json
# Data was successfully imported: data/regular_season/2023/2023_1222.json
# Data was successfully imported: data/regular_season/2023/2023_1223.json
# Data was successfully imported: data/regular_season/2023/2023_1224.json
# Data was successfully imported: data/regular_season/2023/2023_1225.json
# Data was successfully imported: data/regular_season/2023/2023_1226.json
# Data was successfully imported: data/regular_season/2023/2023_1227.json
# Data was successfully imported: data/regular_season/2023/2023_1228.json
# Data was successfully imported: data/regular_season/2023/2023_1229.json
# Data was successfully imported: data/regular_season/2023/2023_1230.json
# Data was successfully imported: data/regular_season/2023/2023_1231.json
# Data was successfully imported: data/regular_season/2023/2023_1232.json
# Data was successfully imported: data/regular_season/2023/2023_1233.json
# Data was successfully imported: data/regular_season/2023/2023_1234.json
# Data was successfully imported: data/regular_season/2023/2023_1235.json
# Data was successfully imported: data/regular_season/2023/2023_1236.json
# Data was successfully imported: data/regular_season/2023/2023_1237.json
# Data was successfully imported: data/regular_season/2023/2023_1238.json
# Data was successfully imported: data/regular_season/2023/2023_1239.json
# Data was successfully imported: data/regular_season/2023/2023_1240.json
# Data was successfully imported: data/regular_season/2023/2023_1241.json
# Data was successfully imported: data/regular_season/2023/2023_1242.json
# Data was successfully imported: data/regular_season/2023/2023_1243.json
# Data was successfully imported: data/regular_season/2023/2023_1244.json
# Data was successfully imported: data/regular_season/2023/2023_1245.json
# Data was successfully imported: data/regular_season/2023/2023_1246.json
# Data was successfully imported: data/regular_season/2023/2023_1247.json
# Data was successfully imported: data/regular_season/2023/2023_1248.json
# Data was successfully imported: data/regular_season/2023/2023_1249.json
# Data was successfully imported: data/regular_season/2023/2023_1250.json
# Data was successfully imported: data/regular_season/2023/2023_1251.json
# Data was successfully imported: data/regular_season/2023/2023_1252.json
# Data was successfully imported: data/regular_season/2023/2023_1253.json
# Data was successfully imported: data/regular_season/2023/2023_1254.json
# Data was successfully imported: data/regular_season/2023/2023_1255.json
# Data was successfully imported: data/regular_season/2023/2023_1256.json
# Data was successfully imported: data/regular_season/2023/2023_1257.json
# Data was successfully imported: data/regular_season/2023/2023_1258.json
# Data was successfully imported: data/regular_season/2023/2023_1259.json
# Data was successfully imported: data/regular_season/2023/2023_1260.json
# Data was successfully imported: data/regular_season/2023/2023_1261.json
# Data was successfully imported: data/regular_season/2023/2023_1262.json
# Data was successfully imported: data/regular_season/2023/2023_1263.json
# Data was successfully imported: data/regular_season/2023/2023_1264.json
# Data was successfully imported: data/regular_season/2023/2023_1265.json
# Data was successfully imported: data/regular_season/2023/2023_1266.json
# Data was successfully imported: data/regular_season/2023/2023_1267.json
# Data was successfully imported: data/regular_season/2023/2023_1268.json
# Data was successfully imported: data/regular_season/2023/2023_1269.json
# Data was successfully imported: data/regular_season/2023/2023_1270.json
# Data was successfully imported: data/regular_season/2023/2023_1271.json
# Data was successfully imported: data/regular_season/2023/2023_1272.json
# Data was successfully imported: data/regular_season/2023/2023_1273.json
# Data was successfully imported: data/regular_season/2023/2023_1274.json
# Data was successfully imported: data/regular_season/2023/2023_1275.json
# Data was successfully imported: data/regular_season/2023/2023_1276.json
# Data was successfully imported: data/regular_season/2023/2023_1277.json
# Data was successfully imported: data/regular_season/2023/2023_1278.json
# Data was successfully imported: data/regular_season/2023/2023_1279.json
# Data was successfully imported: data/regular_season/2023/2023_1280.json
# Data was successfully imported: data/regular_season/2023/2023_1281.json
# Data was successfully imported: data/regular_season/2023/2023_1282.json
# Data was successfully imported: data/regular_season/2023/2023_1283.json
# Data was successfully imported: data/regular_season/2023/2023_1284.json
# Data was successfully imported: data/regular_season/2023/2023_1285.json
# Data was successfully imported: data/regular_season/2023/2023_1286.json
# Data was successfully imported: data/regular_season/2023/2023_1287.json
# Data was successfully imported: data/regular_season/2023/2023_1288.json
# Data was successfully imported: data/regular_season/2023/2023_1289.json
# Data was successfully imported: data/regular_season/2023/2023_1290.json
# Data was successfully imported: data/regular_season/2023/2023_1291.json
# Data was successfully imported: data/regular_season/2023/2023_1292.json
# Data was successfully imported: data/regular_season/2023/2023_1293.json
# Data was successfully imported: data/regular_season/2023/2023_1294.json
# Data was successfully imported: data/regular_season/2023/2023_1295.json
# Data was successfully imported: data/regular_season/2023/2023_1296.json
# Data was successfully imported: data/regular_season/2023/2023_1297.json
# Data was successfully imported: data/regular_season/2023/2023_1298.json
# Data was successfully imported: data/regular_season/2023/2023_1299.json
# Data was successfully imported: data/regular_season/2023/2023_1300.json
# Data was successfully imported: data/regular_season/2023/2023_1301.json
# Data was successfully imported: data/regular_season/2023/2023_1302.json
# Data was successfully imported: data/regular_season/2023/2023_1303.json
# Data was successfully imported: data/regular_season/2023/2023_1304.json
# Data was successfully imported: data/regular_season/2023/2023_1305.json
# Data was successfully imported: data/regular_season/2023/2023_1306.json
# Data was successfully imported: data/regular_season/2023/2023_1307.json
# Data was successfully imported: data/regular_season/2023/2023_1308.json
# Data was successfully imported: data/regular_season/2023/2023_1309.json
# Data was successfully imported: data/regular_season/2023/2023_1310.json
# Data was successfully imported: data/regular_season/2023/2023_1311.json
# Data was successfully imported: data/regular_season/2023/2023_1312.json
# Data imported: 1312
# Data was successfully imported: data/playoffs/2023/2023_0111.json
# Data was successfully imported: data/playoffs/2023/2023_0112.json
# Data was successfully imported: data/playoffs/2023/2023_0113.json
# Data was successfully imported: data/playoffs/2023/2023_0114.json
# Data was successfully imported: data/playoffs/2023/2023_0115.json
# Data was successfully imported: data/playoffs/2023/2023_0121.json
# Data was successfully imported: data/playoffs/2023/2023_0122.json
# Data was successfully imported: data/playoffs/2023/2023_0123.json
# Data was successfully imported: data/playoffs/2023/2023_0124.json
# Data was successfully imported: data/playoffs/2023/2023_0125.json
# Data was successfully imported: data/playoffs/2023/2023_0126.json
# Data was successfully imported: data/playoffs/2023/2023_0127.json
# Data was successfully imported: data/playoffs/2023/2023_0131.json
# Data was successfully imported: data/playoffs/2023/2023_0132.json
# Data was successfully imported: data/playoffs/2023/2023_0133.json
# Data was successfully imported: data/playoffs/2023/2023_0134.json
# Data was successfully imported: data/playoffs/2023/2023_0141.json
# Data was successfully imported: data/playoffs/2023/2023_0142.json
# Data was successfully imported: data/playoffs/2023/2023_0143.json
# Data was successfully imported: data/playoffs/2023/2023_0144.json
# Data was successfully imported: data/playoffs/2023/2023_0145.json
# Data was successfully imported: data/playoffs/2023/2023_0151.json
# Data was successfully imported: data/playoffs/2023/2023_0152.json
# Data was successfully imported: data/playoffs/2023/2023_0153.json
# Data was successfully imported: data/playoffs/2023/2023_0154.json
# Data was successfully imported: data/playoffs/2023/2023_0155.json
# Data was successfully imported: data/playoffs/2023/2023_0156.json
# Data was successfully imported: data/playoffs/2023/2023_0157.json
# Data was successfully imported: data/playoffs/2023/2023_0161.json
# Data was successfully imported: data/playoffs/2023/2023_0162.json
# Data was successfully imported: data/playoffs/2023/2023_0163.json
# Data was successfully imported: data/playoffs/2023/2023_0164.json
# Data was successfully imported: data/playoffs/2023/2023_0165.json
# Data was successfully imported: data/playoffs/2023/2023_0171.json
# Data was successfully imported: data/playoffs/2023/2023_0172.json
# Data was successfully imported: data/playoffs/2023/2023_0173.json
# Data was successfully imported: data/playoffs/2023/2023_0174.json
# Data was successfully imported: data/playoffs/2023/2023_0175.json
# Data was successfully imported: data/playoffs/2023/2023_0176.json
# Data was successfully imported: data/playoffs/2023/2023_0181.json
# Data was successfully imported: data/playoffs/2023/2023_0182.json
# Data was successfully imported: data/playoffs/2023/2023_0183.json
# Data was successfully imported: data/playoffs/2023/2023_0184.json
# Data was successfully imported: data/playoffs/2023/2023_0185.json
# Data was successfully imported: data/playoffs/2023/2023_0211.json
# Data was successfully imported: data/playoffs/2023/2023_0212.json
# Data was successfully imported: data/playoffs/2023/2023_0213.json
# Data was successfully imported: data/playoffs/2023/2023_0214.json
# Data was successfully imported: data/playoffs/2023/2023_0215.json
# Data was successfully imported: data/playoffs/2023/2023_0216.json
# Data was successfully imported: data/playoffs/2023/2023_0221.json
# Data was successfully imported: data/playoffs/2023/2023_0222.json
# Data was successfully imported: data/playoffs/2023/2023_0223.json
# Data was successfully imported: data/playoffs/2023/2023_0224.json
# Data was successfully imported: data/playoffs/2023/2023_0225.json
# Data was successfully imported: data/playoffs/2023/2023_0226.json
# Data was successfully imported: data/playoffs/2023/2023_0231.json
# Data was successfully imported: data/playoffs/2023/2023_0232.json
# Data was successfully imported: data/playoffs/2023/2023_0233.json
# Data was successfully imported: data/playoffs/2023/2023_0234.json
# Data was successfully imported: data/playoffs/2023/2023_0235.json
# Data was successfully imported: data/playoffs/2023/2023_0236.json
# Data was successfully imported: data/playoffs/2023/2023_0241.json
# Data was successfully imported: data/playoffs/2023/2023_0242.json
# Data was successfully imported: data/playoffs/2023/2023_0243.json
# Data was successfully imported: data/playoffs/2023/2023_0244.json
# Data was successfully imported: data/playoffs/2023/2023_0245.json
# Data was successfully imported: data/playoffs/2023/2023_0246.json
# Data was successfully imported: data/playoffs/2023/2023_0247.json
# Data was successfully imported: data/playoffs/2023/2023_0311.json
# Data was successfully imported: data/playoffs/2023/2023_0312.json
# Data was successfully imported: data/playoffs/2023/2023_0313.json
# Data was successfully imported: data/playoffs/2023/2023_0314.json
# Data was successfully imported: data/playoffs/2023/2023_0315.json
# Data was successfully imported: data/playoffs/2023/2023_0316.json
# Data was successfully imported: data/playoffs/2023/2023_0321.json
# Data was successfully imported: data/playoffs/2023/2023_0322.json
# Data was successfully imported: data/playoffs/2023/2023_0323.json
# Data was successfully imported: data/playoffs/2023/2023_0324.json
# Data was successfully imported: data/playoffs/2023/2023_0325.json
# Data was successfully imported: data/playoffs/2023/2023_0326.json
# Data was successfully imported: data/playoffs/2023/2023_0411.json
# Data was successfully imported: data/playoffs/2023/2023_0412.json
# Data was successfully imported: data/playoffs/2023/2023_0413.json
# Data was successfully imported: data/playoffs/2023/2023_0414.json
# Data was successfully imported: data/playoffs/2023/2023_0415.json
# Data was successfully imported: data/playoffs/2023/2023_0416.json
# Data was successfully imported: data/playoffs/2023/2023_0417.json
# Data imported: 88
#        idGame periodType currentPeriod              timeInPeriod  \
# 0  2022020124        REG           1/3 2022-10-28 23:02:45+00:00
# 1  2022020124        REG           1/3 2022-10-28 23:03:42+00:00
# 2  2022020124        REG           1/3 2022-10-28 23:04:53+00:00
# 3  2022020124        REG           1/3 2022-10-28 23:04:57+00:00
# 4  2022020124        REG           1/3 2022-10-28 23:07:30+00:00
#
#   situationCode eventOwnerTeam   typeDescKey    iceCoord       shootingPlayer  \
# 0          1551      Islanders  shot-on-goal    (34, 31)        Sebastian Aho
# 1          1551      Islanders  shot-on-goal   (78, -16)  Jean-Gabriel Pageau
# 2          1551     Hurricanes  shot-on-goal   (-45, 34)          Brett Pesce
# 3          1551     Hurricanes  shot-on-goal    (-74, 7)          Jesper Fast
# 4          1551     Hurricanes  shot-on-goal  (-13, -30)    Andrei Svechnikov
#
#         goaliePlayer   shotType teamSide  emptyGoalNet isGoalAdvantage  \
# 0  Frederik Andersen       slap     away         False         Neutral
# 1  Frederik Andersen  deflected     away         False         Neutral
# 2       Ilya Sorokin       slap     home         False         Neutral
# 3       Ilya Sorokin      wrist     home         False         Neutral
# 4       Ilya Sorokin      wrist     home         False         Neutral
#
#    shotDistance
# 0          63.1
# 1          19.4
# 2          55.6
# 3          16.6
# 4          81.7

# %% [markdown]
# ## 5. Visualisation avancée

# %%
# Récupérer tous les données de 2022
data_2022 = get_data_from(2022,2022)
# Out:
# Data imported: 1312
# Data imported: 88

# %%
# Récupérer le nom de chaque équipe de l'année 2022
teams = pd.concat([df['eventOwnerTeam'] for df in data_2022[2022]])
unique_teams = teams.unique()
print(unique_teams)
# Out:
# ['Sharks' 'Predators' 'Lightning' 'Rangers' 'Golden Knights' 'Kings'
#  'Capitals' 'Bruins' 'Hurricanes' 'Blue Jackets' 'Maple Leafs' 'Canadiens'
#  'Avalanche' 'Blackhawks' 'Ducks' 'Kraken' 'Canucks' 'Oilers' 'Penguins'
#  'Coyotes' 'Flyers' 'Devils' 'Senators' 'Sabres' 'Panthers' 'Islanders'
#  'Stars' 'Wild' 'Flames' 'Red Wings' 'Jets' 'Blues']

# %% [markdown]
# #### Here I need to create a dictionary with a DataFrame for each team. Those DataFrames will contain all the shots made by each teams for the season 2022, including playoffs.

# %%
# Dictionary that will have one DataFrame per team, where the team's name is the key
team_shots_dfs = {}
dfs_list = data_2022[2022] # Simplify

# Loop over each team and filter rows accordingly
for team in unique_teams:
    
    # Creates a DataFrame with only the shots made by a specific team
    team_df = pd.concat([df[df['eventOwnerTeam'] == team] for df in dfs_list])
    
    # Add the new DataFrame to the team_shots_dfs dictionary
    team_shots_dfs[team] = team_df

# %%
# Example of teams shots by the San Jose Sharks
team_shots_dfs['Sharks'].head()
# Out:
#         idGame periodType currentPeriod              timeInPeriod  \
# 0   2022020001        REG           1/3 2022-10-07 18:00:23+00:00
# 4   2022020001        REG           1/3 2022-10-07 18:02:42+00:00
# 6   2022020001        REG           1/3 2022-10-07 18:04:19+00:00
# 7   2022020001        REG           1/3 2022-10-07 18:04:44+00:00
# 10  2022020001        REG           1/3 2022-10-07 18:08:08+00:00
#
#    situationCode eventOwnerTeam   typeDescKey  iceCoord  shootingPlayer  \
# 0           1551         Sharks  shot-on-goal   (44, 8)      Timo Meier
# 4           1551         Sharks  shot-on-goal   (72, 2)  Steven Lorentz
# 6           1551         Sharks  shot-on-goal  (49, 12)  Oskar Lindblom
# 7           1551         Sharks  shot-on-goal  (46, 18)    Kevin Labanc
# 10          1541         Sharks  shot-on-goal  (60, 17)    Kevin Labanc
#
#    goaliePlayer shotType teamSide  emptyGoalNet isGoalAdvantage  shotDistance
# 0   Juuse Saros    wrist     away         False         Neutral          45.7
# 4   Juuse Saros   tip-in     away         False         Neutral          17.1
# 6   Juuse Saros    wrist     away         False         Neutral          41.8
# 7   Juuse Saros     slap     away         False         Neutral          46.6
# 10  Juuse Saros    wrist     away         False       Advantage          33.6
